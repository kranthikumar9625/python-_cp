# %% [markdown]
# # Bitwise operators in python

# %% [markdown]
# Bitwise oprators are most important in compitative programinng.
#
# Bitwise operators execute faster than the arthimetic operators.
# Following are the Bitwise operators we have. we look into them one by one
#
# ![types-of-bitwise-operators.jpg](attachment:types-of-bitwise-operators.jpg)

# %% [markdown]
# ### Bitwise AND
#
# let us develop a code to give even numbers from a set of numbers using Bitwise AND

# %%
n = int(input('give the number'))
for i in range(1,n+1):
    if i&1 == 0:
        print(i,"odd ")
    else:
        print(i,"even")
# Out:
# give the number6
# 1 even
# 2 odd
# 3 even
# 4 odd
# 5 even
# 6 odd

# %% [markdown]
# In the above case 'i' and 1 are converted into binary numbers and the '&' condition is applied.
#
# for example:
#
# 1&1 => 01
#         &
#        01 = 01 (even)
#
# 2&1 = > 10 & 01 = 00 (odd)

# %% [markdown]
# ### Bitwise OR
# print numbers which are divided by 3 or 5 in a range of numbers using bitwise or

# %%
n = int(input('give the number'))
for i in range(1,n+1):
    if i%3 == 0 | i%5 == 0:
        print(i,"divisible by 3 or 5 ")
    else:
        print(i,"not divisible by 3 or 5")
# Out:
# give the number8
# 1 not divisible by 3 or 5
# 2 not divisible by 3 or 5
# 3 not divisible by 3 or 5
# 4 not divisible by 3 or 5
# 5 not divisible by 3 or 5
# 6 not divisible by 3 or 5
# 7 not divisible by 3 or 5
# 8 not divisible by 3 or 5

# %% [markdown]
# ### Bitwise XOR
# Swap two numbers using XOR

# %%
a=5 # a = 101
b=6 # b = 110

# %%
a = a^b #101 ^ 110 = 011
b = a^b #011 ^ 110 = 101
a = a^b #011 ^ 101 = 111
print(a,b)
# Out:
# 6 5

# %% [markdown]
# ### Left shift
#
# Left shift is used for multiplication
#
# multiply a number with power of 2

# %%
x = int(input('enter the number'))

print(x << 2) # 16 * 2 power 2
# Out:
# enter the number16
# 64

# %% [markdown]
# ### Right shift
#
# Right shift is used for division
#
# divide a number with power of 2

# %%
x = int(input('enter the number'))

print(x >> 3) # 16 % 2 power 3
# Out:
# enter the number16
# 2
